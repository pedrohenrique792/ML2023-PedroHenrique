# %% [markdown]
# <a href="https://colab.research.google.com/github/pedrohenrique792/ML2023-PedroHenrique/blob/main/C%C3%B3pia_de_4_Correla%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 4 - Correlação
# **Direto ao ponto**: correlação é o coeficiente de interdependência entre duas ou mais variáveis.
#
# Em muitos casos, quando analisamos algumas variáveis, essa interdependência é muito clara. Exemplo:
# - Massa corporal e altura,
# - Consumo de combustível e distância percorrida,
# - Número de anúncios e produtos vendidos,
# - Tempo de estudo e desempenho na avaliação.
#
# Entretanto, algumas vezes essa correlação pode não ser muito clara.

# %% [markdown]
# ## Correlações positivas

# %% [markdown]
# 1.   Importa a biblioteca numpy
# 2.   Variável x recebe um array de numero aleatórios
# 3.   Variável y recebe um array da soma de x + outro array de numero aleatórios
# 4.   Cria o coeficientede correlação de x e y

# %%
import numpy as np

np.random.seed(1)

# 1000 random integers between 0 and 50
x = np.random.randint(0, 50, 1000)

# Positive Correlation with some noise
y = x + np.random.normal(0, 10, 1000)

np.corrcoef(x, y)
# Out:
# array([[1.        , 0.81543901],
#        [0.81543901, 1.        ]])

# %% [markdown]
# Cria um gráfico de dispersão de x e y

# %%
# import matplotlib
import matplotlib.pyplot as plt

plt.scatter(x, y)

# %% [markdown]
# ## Correlações negativas

# %% [markdown]
# 1.   Variável x recebe um array de numero aleatórios
# 2.   Variável y recebe um array da seguinte equação: 100 - x + outro array de numero aleatórios
# 3.   Cria o coeficientede correlação de x e y

# %%
# 1000 random integers between 0 and 50
x = np.random.randint(0, 50, 1000)

# Negative Correlation with some noise
y = 100 - x + np.random.normal(0, 5, 1000)

np.corrcoef(x, y)
# Out:
# array([[ 1.        , -0.94957116],
#        [-0.94957116,  1.        ]])

# %% [markdown]
# Cria um gráfico de dispersão de x e y

# %%
plt.scatter(x, y)

# %% [markdown]
# ## Correlação fraca ou sem correlação

# %% [markdown]
# 1.   Variável x recebe um array de numero aleatórios
# 2.   Variável y recebe um array de numero aleatórios
# 3.   Cria o coeficientede correlação de x e y

# %%
x = np.random.randint(0, 50, 1000)
y = np.random.randint(0, 50, 1000)

np.corrcoef(x, y)
# Out:
# array([[ 1.        , -0.00554681],
#        [-0.00554681,  1.        ]])

# %% [markdown]
# Cria um gráfico de dispersão de x e y

# %%
plt.scatter(x, y)

# %% [markdown]
# ## Correlação é diferente de causalidade!

# %% [markdown]
# ![download (1).png](data:image/png;base64,...)
